# %% [markdown]
# # Programming Practice II
# ## 1 Overview
# In this practice, you are asked to implement a neural network with one hidden layer for regression using NumPy only. In particular, you are expected to learn to
# * implement simple activation functions;
# * get familiar with gradient descent algorithms;
# * get familiar with back-propagation algorithms in neural networks.

# %% [markdown]
# ## 2 Tasks
# In this section, you can start the programming practice task by task. Please pay attention to the hints as well as the API documents available online.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.1 Define Sigmoid Function

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))
    # TODO

# %%
# Out:
# [0.00669285 0.01798621 0.04742587 0.11920292 0.26894142 0.5
#  0.73105858 0.88079708 0.95257413 0.98201379]

# %% [markdown]
# ### 2.2 Define Derivative of Sigmoid Function

# %%
def derivative_sigmoid(x):
    return sigmoid(x)*(1-sigmoid(x))
    # TODO

# %%
x = np.linspace(-5,5,50)

print(sigmoid(x))
plt.plot(x,sigmoid(x))
plt.show()

print(derivative_sigmoid(x))
plt.plot(x,derivative_sigmoid(x))
plt.show()
# Out:
# [0.00669285 0.00819568 0.01003256 0.01227603 0.01501357 0.01835024
#  0.0224116  0.02734679 0.03333169 0.04057176 0.04930426 0.05979915
#  0.07235796 0.0873094  0.10500059 0.12578244 0.14998817 0.17790412
#  0.20973382 0.24555731 0.28529068 0.32865255 0.37514569 0.42406149
#  0.47451191 0.52548809 0.57593851 0.62485431 0.67134745 0.71470932
#  0.75444269 0.79026618 0.82209588 0.85001183 0.87421756 0.89499941
#  0.9126906  0.92764204 0.94020085 0.95069574 0.95942824 0.96666831
#  0.97265321 0.9775884  0.98164976 0.98498643 0.98772397 0.98996744
#  0.99180432 0.99330715]
# [0.00664806 0.00812851 0.0099319  0.01212532 0.01478816 0.01801351
#  0.02190932 0.02659894 0.03222069 0.03892569 0.04687335 0.05622321
#  0.06712229 0.07968647 0.09397546 0.10996122 0.12749172 0.14625425
#  0.16574555 0.18525892 0.20389991 0.22064005 0.2344114  0.24423334
#  0.24935036 0.24935036 0.24423334 0.2344114  0.22064005 0.20389991
#  0.18525892 0.16574555 0.14625425 0.12749172 0.10996122 0.09397546
#  0.07968647 0.06712229 0.05622321 0.04687335 0.03892569 0.03222069
#  0.02659894 0.02190932 0.01801351 0.01478816 0.01212532 0.0099319
#  0.00812851 0.00664806]

# %% [markdown]
# ### 2.3 Plot Functions

# %%
# TODO: plotting

# %% [markdown]
# ### 2.4 Define Neural Network

# %%
def forward_pass(x, w1, b1, w2, b2):
    # TODO

# %% [markdown]
# ### 2.5 Define Loss Function

# %%
def mse(y_true, y_pred):
    # TODO

def derivative_mse(y_true, y_pred):
    # TODO

# %% [markdown]
# ### 2.6 Define Gradient

# %%
def cal_gradient(x, y, y_hat, w1, b1, w2, b2):
    # TODO
    # return dLdw1, dLdb1, dLdw2, dLdb2

# %% [markdown]
# ### 2.7 Update Weights

# %%
def update_parameters(parameters, gradient, learning_rate):
    # TODO

# %% [markdown]
# ### 2.8 Train Network

# %%
# TODO: datasets

# TODO: hyperparameters

# TODO: parameter initialization

# TODO: training

# %% [markdown]
# ### 2.9 Plot Results

# %%
# TODO: plotting for comparison between the prediction and ground truth

# %%
# TODO: plotting for the loss
